# %%
# Лабораторна робота №2
## Встановлення Anaconda та OpenCV
Прізвище: Семенко

# %%
# !conda --version
# Out:
# conda 26.1.1

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# # * -> active
# # + -> frozen
# base                     C:\Anaconda
# Semenko_OpenCV       *   C:\Anaconda\envs\Semenko_OpenCV

# %%
import sys
print(sys.version)
# Out:
# 3.13.13 | packaged by Anaconda, Inc. | (main, Apr 14 2026, 06:12:50) [MSC v.1942 64 bit (AMD64)]

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0
